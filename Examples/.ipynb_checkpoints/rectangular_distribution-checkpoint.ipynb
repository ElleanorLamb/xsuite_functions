# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals
import matplotlib.pyplot as plt
from time import time
import sys
from abel.direct import direct_transform
from abel.tools.analytical import GaussianAnalytical
from xbeamfit import fitting
from xbeamfit import distributions 
import json
import numpy as np
import scipy as sp
import pandas as pd
import sys
import xbeamfit as xb 
from scipy import interpolate
from numpy import trapz
import scipy.integrate as integrate
from scipy import special
from scipy.stats import norm

from scipy.stats import chi
from scipy.stats import chi2
from xsuite_functions import footprint as fp

# %%
# find r from an abel transform of a q-gauss

x = np.linspace(-2,2,20000)

y = []

for i in range(5000):
    y.append(0)
for i in range(10000):
    y.append(np.pi)
for i in range(5000):
    y.append(0)



############ Inverse Abel transform 

r = np.linspace(0.00001,2.00001,10000)
abel_qgauss = direct_transform(y[10000:], dr=np.diff(r)[0], direction="inverse", correction=True)

abel_qgauss_r = abel_qgauss

abel_forward = direct_transform(abel_qgauss_r, dr=np.diff(r)[0], direction="forward", correction=True)
# Out:
# ...
# Falling back to a pure Python backend...
# ...
# Falling back to a pure Python backend...

# %%
plt.plot(x, y)
plt.plot(r, abel_qgauss_r)
plt.plot(r, abel_forward)
plt.grid()
rp = np.linspace(0,1,1000)
func_r = 1/np.sqrt(1-rp**2)
plt.plot(rp,func_r, label='$1/\\sqrt{1-r^2}$')
#plt.xlim([0,4])
# Out:
# /tmp/ipykernel_1903149/2885152493.py:6: RuntimeWarning: divide by zero encountered in divide
#   func_r = 1/np.sqrt(1-rp**2)

# %%
abel_qgauss_rect = abel_qgauss*2*np.pi*r




xq= abel_qgauss_rect/np.sum(abel_qgauss_rect)
xq = np.nan_to_num(xq)

r_hist = np.random.choice(a=r,p=xq,size=100000)
theta_hist  = np.random.uniform(0,2*np.pi,size=100000)

# %%
plt.hist(r_hist*np.cos(theta_hist), bins=400, range=[-20,20
                                                    ],density=True, alpha=0.25,  label='x sampled from Abel transform of a rectangular distribution');
plt.hist(r_hist*np.sin(theta_hist), bins=400, range=[-20,20],density=True, alpha=0.25, label='x` sampled from Abel transform of a rectangular distribution');
plt.xlim([-8,8],)
plt.plot(x,np.array(y)/(2*np.pi), label='rectangle distribution')

plt.xlabel('x, x`')

plt.ylabel('PDF')

plt.title('Rectangular distibution')
plt.legend()
plt.grid()
plt.tight_layout()

plt.savefig('./presentation_plots/abel_compare_sampled_rectangular_projection.png', dpi=400)

# %%
plt.hist(r_hist*r_hist, density=1)
# Out:
# (array([0.51610899, 0.54220439, 0.57719822, 0.61699121, 0.67518094,
#         0.74956783, 0.83545268, 1.00502278, 1.31276852, 3.16774143]),
#  array([4.37008265e-05, 1.00061334e-01, 2.00078967e-01, 3.00096600e-01,
#         4.00114233e-01, 5.00131866e-01, 6.00149500e-01, 7.00167133e-01,
#         8.00184766e-01, 9.00202399e-01, 1.00022003e+00]),
#  <BarContainer object of 10 artists>)

# %%
xr=r_hist*np.cos(theta_hist)
xpr=r_hist*np.sin(theta_hist)
plt.plot(xr,xpr,'.',ms=.1)
plt.axis('square')
plt.xlabel('x')
plt.ylabel('x`')
plt.grid()
plt.legend()
plt.title('Rectangular beam in phase-space')
plt.tight_layout()
plt.savefig('presentation_plots/rectangle_phase_space.png',dpi=400)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
r_hist
# Out:
# array([0.97130713, 0.84189419, 0.95870587, ..., 0.99070907, 0.97570757,
#        0.95410541])

# %%
plt.hist(r_hist, bins=400, density=True, label='$\\rho(r)$');
rp = np.linspace(0,1,1000)
#func_r = 1/np.sqrt(1-rp**2)
#plt.plot(rp,func_r, label='$1/\\sqrt{1-r^2}$')
plt.hist(theta_hist, bins=400, density=True, label='$\\theta$');
plt.xlabel('$\\rho, \\theta$ ')
plt.ylabel('PDF')
plt.grid()
plt.legend()
plt.ylim([0,10])
plt.savefig('presentation_plots/hist_r_theta_rectangle.png', dpi=400)
