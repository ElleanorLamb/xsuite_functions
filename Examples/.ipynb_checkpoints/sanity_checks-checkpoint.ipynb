# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals
import matplotlib.pyplot as plt
from time import time
import sys
from abel.direct import direct_transform
from abel.tools.analytical import GaussianAnalytical
from xbeamfit import fitting
from xbeamfit import distributions 
import json
import numpy as np
import scipy as sp
import pandas as pd
import sys
import xbeamfit as xb 
from scipy import interpolate
from numpy import trapz
import scipy.integrate as integrate
from scipy import special
from scipy.stats import norm

from scipy.stats import chi
from scipy.stats import chi2
from xsuite_functions import footprint as fp

# %%
# the summed profile in x 


x_input = np.linspace(-20,20,20000)

q0 = 1

b0 =  1/(5-3*q0)
#sigma = 1/((b0)*(5-3*q0))
A0 = 1

# %%
# find r from an abel transform of a q-gauss

x = np.linspace(-100,100,20000)

q0=1
b0 =  1/(5-3*q0)


qgauss = xb.distributions.qGauss(x,mu=0,q=q0,A=1,b=b0)
qgauss = np.nan_to_num(qgauss, 0)


############ Inverse Abel transform 

r = np.linspace(0.00001,100.00001,10000)
abel_qgauss = direct_transform(qgauss[10000:], dr=np.diff(r)[0], direction="Inverse", correction=True)

#abel_qgauss*2*np.pi*r

abel_qgauss = abel_qgauss*r
# Out:
# Warning: Cython extensions were not built,                     the C backend is not available!
# Falling back to a pure Python backend...

# %%
xq= abel_qgauss/np.sum(abel_qgauss)
xq = np.nan_to_num(xq)

r_hist = np.random.choice(a=r,p=xq,size=100000)
theta_hist  = np.random.uniform(0,2*np.pi,size=100000)

# %%
plt.hist(theta_hist);
plt.hist(r_hist, bins=400, range=[0,10], density=True);

# %%
plt.hist(r_hist, 400, density=True, range=[0,10]);
plt.plot(r, abel_qgauss)
plt.xlim([0,10])
# Out:
# (0.0, 10.0)

# %%
plt.hist(r_hist*np.cos(theta_hist), bins=400, range=[-20,20
                                                    ],density=True, alpha=0.25
        );
plt.plot(x,qgauss)
plt.hist(r_hist*np.sin(theta_hist), bins=400, range=[-20,20],density=True, alpha=0.25);
plt.xlim([-10,10])
plt.xlabel('x')
plt.ylabel('PDF')
# Out:
# (-10.0, 10.0)
