# %%
from matplotlib import pyplot as plt 
import scipy as sp

import numpy as np

import NAFFlib
import json
import xtrack as xt
import xpart as xp
import xobjects as xo 

from scipy.constants import c as speed_c
from scipy.constants import e as qe
from scipy.constants import m_p
import pandas as pd
import sys
import math
import xdeps as xd
from xdeps.madxutils import MadxEval
import conda
import time



def generate_coordGrid(xRange,yRange,labels = ['x','y'],nPoints=100):
    '''
    
    Temporary function from BBfootprint change to BBfootprint installation after Philippe has implemented it 
    
    Distribute points uniformly on a 2D grid.
    -----------------------------------------
    Input:
        xRange : range of first coordinate
        yRange : range of second coordinate
        labels : labels to be used in the resulting dataframe
        nPoint : total number of points to generate (sqrt(nPoints) for each coordinate)
    Returns:
        coordinates: dataframe containing the distributed points
    '''

    if type(xRange) is list and type(yRange) is list:
        xVec = np.linspace(xRange[0],xRange[1],int(np.sqrt(nPoints)))
        yVec = np.linspace(yRange[0],yRange[1],int(np.sqrt(nPoints)))
    else:
        xVec = xRange
        yVec = yRange
        
    xx,yy = np.meshgrid(xVec,yVec)
    xx,yy = xx.flatten(),yy.flatten()

    return pd.DataFrame(dict(zip(labels,[xx,yy])))

# %%
# load the line 


with open('../Examples/xtrack_release20_bb.json', 'r') as fid: # tune further from diagonal no bb
    loaded_dct = json.load(fid)
line = xt.Line.from_dict(loaded_dct)

line.particle_ref = xp.Particles(mass0=xp.PROTON_MASS_EV, q0=1,
                        gamma0=6800/0.938)
part_ref = line.particle_ref 

context = xo.ContextCpu()         # For GPU
# Out:
# Done loading line from dict.

# %%
tracker=line.build_tracker()
# Out:
# generating ./10a92d5985854f2f8d266171d13aa0f5.c
# the current directory is '/home/elamb/xsuite_functions/xsuite_functions'
# running build_ext
# building '10a92d5985854f2f8d266171d13aa0f5' extension
# gcc -pthread -B /home/elamb/clean/executable/py_29_02_22/miniconda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/elamb/clean/executable/py_29_02_22/miniconda/include -I/home/elamb/clean/executable/py_29_02_22/miniconda/include -fPIC -O2 -isystem /home/elamb/clean/executable/py_29_02_22/miniconda/include -fPIC -I/home/elamb/clean/executable/py_29_02_22/miniconda/include/python3.9 -c 10a92d5985854f2f8d266171d13aa0f5.c -o ./10a92d5985854f2f8d266171d13aa0f5.o -std=c99 -O3 -Wno-unused-function
# gcc -pthread -B /home/elamb/clean/executable/py_29_02_22/miniconda/compiler_compat -shared -Wl,-rpath,/home/elamb/clean/executable/py_29_02_22/miniconda/lib -Wl,-rpath-link,/home/elamb/clean/executable/py_29_02_22/miniconda/lib -L/home/elamb/clean/executable/py_29_02_22/miniconda/lib -L/home/elamb/clean/executable/py_29_02_22/miniconda/lib -Wl,-rpath,/home/elamb/clean/executable/py_29_02_22/miniconda/lib -Wl,-rpath-link,/home/elamb/clean/executable/py_29_02_22/miniconda/lib -L/home/elamb/clean/executable/py_29_02_22/miniconda/lib ./10a92d5985854f2f8d266171d13aa0f5.o -o ./10a92d5985854f2f8d266171d13aa0f5.cpython-39-x86_64-linux-gnu.so -std=c99 -O3

# %%
print('\nInitial twiss parameters')
tw_before = tracker.twiss()
print(f"Qx = {tw_before['qx']:.5f} Qy = {tw_before['qy']:.5f} "
      f"Q'x = {tw_before['dqx']:.5f} Q'y = {tw_before['dqy']:.5f}")
# Out:
# Initial twiss parameters
# Qx = 62.28963 Qy = 60.30240 Q'x = 14.45716 Q'y = 15.46175

# %%
allVars = list(tracker.vars._owner.keys())
allElements = list(tracker.element_refs._owner.keys())

[name for name in allVars if ('oct' in name)]
# Out:
# ['all_oct_ON']

# %%
tracker.['on_bb_charge']._info()
# Out:
# #  vars['on_bb_charge']._get_value()
#    vars['on_bb_charge'] = 1.0
#
# #  vars['on_bb_charge']._expr is None
#
# #  vars['on_bb_charge'] does not influence any target

# %%
beam = 'b1'
# Deactivating all wires
#===================================================
tracker.vars['enable_qff'] = 0
for IP in ['ip1','ip5']:
    tracker.vars[f"bbcw_rw_{IP}.{beam}"] = 1
    tracker.vars[f"bbcw_i_{IP}.{beam}"]  = 0

    
# Creating BB knobs
#===================================================
allVars = list(tracker.vars._owner.keys())
allElements = list(tracker.element_refs._owner.keys())


for _ip in ['ip1','ip5','ip2','ip8']:
    bb_lr = [name for name in allElements if ('bb_lr' in name)&(f'{_ip[-1]}b1' in name)]
    bb_ho = [name for name in allElements if ('bb_ho' in name)&(f'{_ip[-1]}b1' in name)]

    # New knob:
    tracker.vars[f'{_ip}_bblr_ON'] = 1
    tracker.vars[f'{_ip}_bbho_ON'] = 1

    # Linking to new knob
    for _lr in bb_lr:
        tracker.element_refs[_lr].n_particles      = tracker.vars[f'{_ip}_bblr_ON']*tracker.element_refs[_lr].n_particles._value
    for _ho in bb_ho:
        tracker.element_refs[_ho].slices_other_beam_num_particles = tracker.vars[f'{_ip}_bbho_ON']*tracker.element_refs[_ho].slices_other_beam_num_particles._value[0]

# Creating sext and oct knobs
#====================================================
ks = [name for name in allVars if ('ksf' in name)|('ksd' in name)]
ko = [name for name in allVars if ('kof.a' in name)|('kod.a' in name)]

tracker.vars['all_oct_ON']  = 1
tracker.vars['all_sext_ON'] = 1
for _ks in ks:
    if tracker.vars[_ks]._expr is None:
        tracker.vars[_ks] = tracker.vars['all_sext_ON']*tracker.vars[_ks]._value
    else:
        tracker.vars[_ks] = tracker.vars['all_sext_ON']*tracker.vars[_ks]._expr 
for _ko in ko:
    if tracker.vars[_ko]._expr is None:
        tracker.vars[_ko] = tracker.vars['all_oct_ON']*tracker.vars[_ko]._value
    else:
        tracker.vars[_ko] = tracker.vars['all_oct_ON']*tracker.vars[_ko]._expr

# %%
tracker.vars['all_oct_ON']  = 1
tracker.vars['all_sext_ON']  = 1

# %%
tracker.vars['all_oct_ON']  = 0
tracker.vars['all_sext_ON']  = 0

# %%
tracker.vars[f'ip1_bbho_ON'] = 1
tracker.vars[f'ip2_bbho_ON'] = 1
tracker.vars[f'ip5_bbho_ON'] = 1
tracker.vars[f'ip8_bbho_ON'] = 1


tracker.vars[f'ip1_bbho_ON']._value
# Out:
# 1

# %%
tracker.vars[f'ip1_bbho_ON'] = 0
tracker.vars[f'ip2_bbho_ON'] = 0
tracker.vars[f'ip5_bbho_ON'] = 0
tracker.vars[f'ip8_bbho_ON'] = 0

# %%
# have to turn off beambeam before you rematch 



# rematch using the xtrack.tracker.match 


t1 = time.time()


tracker.match(vary=['dqx.b1','dqy.b1','dqpx.b1_sq','dqpy.b1_sq'],
    targets = [
        ('qx', 62.31),
        ('qy',60.32),
        ('dqx', 15.0),
        ('dqy', 15.0),])
              
              
t2 = time.time()

print('\nTime fsolve: ', t2-t1)

tw_final = tracker.twiss()
print('\nFinal twiss parameters bb OFF ')
print(f"Qx = {tw_final['qx']:.5f} Qy = {tw_final['qy']:.5f} "
      f"Q'x = {tw_final['dqx']:.5f} Q'y = {tw_final['dqy']:.5f}")
# Out:
# Time fsolve:  21.52569603919983
#
# Final twiss parameters bb OFF
# Qx = 62.30980 Qy = 60.32000 Q'x = -195.83488 Q'y = -193.67922

# %%
# turn back on the beam-beam



tracker.vars[f'ip1_bbho_ON'] = 1
tracker.vars[f'ip2_bbho_ON'] = 0
tracker.vars[f'ip5_bbho_ON'] = 0
tracker.vars[f'ip8_bbho_ON'] = 0

# %%
# after turning the IP back on 


tw_final = tracker.twiss()
print('\nFinal twiss parameters bb ON')
print(f"Qx = {tw_final['qx']:.5f} Qy = {tw_final['qy']:.5f} "
      f"Q'x = {tw_final['dqx']:.5f} Q'y = {tw_final['dqy']:.5f}")
# Out:
# Final twiss parameters bb ON
# Qx = 62.30078 Qy = 60.31102 Q'x = -201.21821 Q'y = -192.25658

# %%
# make the particle distributions, up to 6 sigma is the usual range 

pi = math.pi
def PointsInCircum(r,n=100):
    return [(math.cos(2*pi/n*x)*r,math.sin(2*pi/n*x)*r) for x in range(0,n+1)] 

n=50

b=PointsInCircum(0.3,n=n)
x_norm03=[]
y_norm03=[]
for i in range(n):
    if b[i][0]>0 and b[i][1]>0:
        x_norm03.append(b[i][0])
        y_norm03.append(b[i][1])


b=PointsInCircum(1,n=n)
x_norm=[]
y_norm=[]
for i in range(n):
    if b[i][0]>0 and b[i][1]>0:
        x_norm.append(b[i][0])
        y_norm.append(b[i][1])

    
b=PointsInCircum(2,n=n)
x_norm1=[]
y_norm1=[]
for i in range(n):
    if b[i][0]>0 and b[i][1]>0:
        x_norm1.append(b[i][0])
        y_norm1.append(b[i][1])
    
b=PointsInCircum(3,n=n)
x_norm2=[]
y_norm2=[]
for i in range(n):
    if b[i][0]>0 and b[i][1]>0:
        x_norm2.append(b[i][0])
        y_norm2.append(b[i][1])

b = PointsInCircum(4,n=n)




x_norm3 =[]
y_norm3 = []
for i in range(n):
    if b[i][0]>0 and b[i][1]>0:
        x_norm3.append(b[i][0])
        y_norm3.append(b[i][1])

        
        
b = PointsInCircum(5.0,n=n)
x_norm4 =[]
y_norm4 = []
for i in range(n):
    if b[i][0]>0 and b[i][1]>0:
        x_norm4.append(b[i][0])
        y_norm4.append(b[i][1])

b = PointsInCircum(6.0,n=n)

x_norm5 =[]
y_norm5 = []
for i in range(n):
    if b[i][0]>0 and b[i][1]>0:
        x_norm5.append(b[i][0])
        y_norm5.append(b[i][1])
points=15



plt.scatter(x_norm03,y_norm03, s=points)
plt.scatter(x_norm,y_norm, s=points)
plt.scatter(x_norm1,y_norm1, s=points)
plt.scatter(x_norm2,y_norm2, s=points)
plt.scatter(x_norm3,y_norm3, s=points)
plt.scatter(x_norm4,y_norm4, s=points)
plt.scatter(x_norm5,y_norm5, s=points)
plt.title('Initial particles for a footprint study')
plt.xlabel('normalised x position (sigmas of beam size)')
plt.ylabel('normalise y position (sigmas of beam size)')
plt.grid()

# %%
x_norm03=np.array(x_norm03)
x_norm=np.array(x_norm)
x_norm1=np.array(x_norm1)
x_norm2=np.array(x_norm2)
x_norm3=np.array(x_norm3)
x_norm4=np.array(x_norm4)
x_norm5=np.array(x_norm5)

y_norm03=np.array(y_norm03)
y_norm=np.array(y_norm)
y_norm1=np.array(y_norm1)
y_norm2=np.array(y_norm2)
y_norm3=np.array(y_norm3)
y_norm4=np.array(y_norm4)
y_norm5=np.array(y_norm5)
x = np.concatenate((x_norm03,x_norm,x_norm1,x_norm2,x_norm3,x_norm4,x_norm5))
y = np.concatenate((y_norm03,y_norm,y_norm1,y_norm2,y_norm3,y_norm4,y_norm5))
dist_x = x
dist_y = y 

# show the particle distribution 
plt.scatter(x,y)

# %%
coordinates = generate_coordGrid(np.array([0.3,1,2,3,4,5,6]),
                                    np.linspace(0.06*np.pi/2,0.92*np.pi/2,7),labels = ['r_n','theta_n'])

coordinates.insert(0,'x_n',coordinates['r_n']*np.cos(coordinates['theta_n']))
coordinates.insert(1,'y_n',coordinates['r_n']*np.sin(coordinates['theta_n']))


x_n = np.array(coordinates['x_n'])
y_n = np.array(coordinates['y_n'])

# %%
np.array(x_n)
# Out:
# array([2.99962990e-01, 9.99876632e-01, 1.99975326e+00, 2.99962990e+00,
#        3.99950653e+00, 4.99938316e+00, 5.99925979e+00, 2.88948770e-01,
#        9.63162567e-01, 1.92632513e+00, 2.88948770e+00, 3.85265027e+00,
#        4.81581283e+00, 5.77897540e+00, 2.59018665e-01, 8.63395551e-01,
#        1.72679110e+00, 2.59018665e+00, 3.45358220e+00, 4.31697775e+00,
#        5.18037330e+00, 2.12132034e-01, 7.07106781e-01, 1.41421356e+00,
#        2.12132034e+00, 2.82842712e+00, 3.53553391e+00, 4.24264069e+00,
#        1.51358287e-01, 5.04527624e-01, 1.00905525e+00, 1.51358287e+00,
#        2.01811050e+00, 2.52263812e+00, 3.02716574e+00, 8.06759462e-02,
#        2.68919821e-01, 5.37839641e-01, 8.06759462e-01, 1.07567928e+00,
#        1.34459910e+00, 1.61351892e+00, 4.71219519e-03, 1.57073173e-02,
#        3.14146346e-02, 4.71219519e-02, 6.28292692e-02, 7.85365866e-02,
#        9.42439039e-02])

# %%
particles = xp.build_particles(_context=context,
                               tracker=tracker, particle_ref=part_ref,
                               zeta=0, delta=0,
                               x_norm=x_n, # in sigmas
                               y_norm=y_n, # in sigmas
                               scale_with_transverse_norm_emitt=(2.5e-06, 2.5e-06)
                               )

tracker.track(particles, num_turns=1024,turn_by_turn_monitor=True); # track for a longer number of turns?

# %%
# find the max amplitude of the frequency 
h = 6 # find 6 maxima along the spectrum 


q_x = []
for k in range(len(x_n)):
    naff_tune = NAFFlib.get_tunes_all(tracker.record_last_track.x[k].copy(),h)
    amp = []
    for i in range(h):
  
        amp.append(np.abs(naff_tune[1][i]))

    for i in range(h):      
        if amp[i]==np.max(amp):
            q_x.append(np.abs(naff_tune[0][i]))
            
q_y = []
for k in range(len(y_n)):
    naff_tune = NAFFlib.get_tunes_all(tracker.record_last_track.y[k].copy(),h)
    amp = []
    for i in range(h):
        amp.append(np.abs(np.abs(naff_tune[1][i])))

    for i in range(h):        
        if amp[i]==np.max(amp):
            q_y.append(np.abs(naff_tune[0][i]))

# %%
# plot the footprint 
plt.figure('FOOTPRINT')
plt.suptitle('HO:1 OCT:0 CHRO:15,15')


points=8

plt.scatter(q_x[0:12],q_y[0:12], label = '0.3 $\sigma$ ', s=points)
plt.scatter(q_x[12:24],q_y[12:24], label = '1.0 $\sigma$ ',s=points)
plt.scatter(q_x[24:36],q_y[24:36], label = '2.0 $\sigma$ ',s=points)
plt.scatter(q_x[36:48],q_y[36:48], label = '3.0 $\sigma$', s=points)
plt.scatter(q_x[48:60],q_y[48:60], label = '4.0 $\sigma$ ', s=points)
plt.scatter(q_x[60:72],q_y[60:72], label = '5.0 $\sigma$ ', s=points)
plt.scatter(q_x[72:84],q_y[72:84], label = '6.0 $\sigma$ ', s=points)

for i in range(12):
    q_x_s1c = [q_x[0+i],q_x[12+i],q_x[24+i],q_x[36+i],q_x[48+i],q_x[60+i],q_x[72+i]]
    q_y_s1c = [q_y[0+i],q_y[12+i],q_y[24+i],q_y[36+i],q_y[48+i],q_y[60+i],q_y[72+i]]
    plt.plot(q_x_s1c,q_y_s1c,'darkgrey')
    

plt.plot(q_x[0:11],q_y[0:11], color='darkgrey', )
plt.plot(q_x[12:23],q_y[12:23], color='darkgrey' , )
plt.plot(q_x[24:35],q_y[24:35], color='darkgrey', )
plt.plot(q_x[36:47],q_y[36:47], color='darkgrey', )
plt.plot(q_x[48:59],q_y[48:59],  color='darkgrey', )
plt.plot(q_x[60:71],q_y[60:71], color='darkgrey',)
plt.plot(q_x[72:84],q_y[72:84],  color='darkgrey',)
    

plt.ylabel('$Q_y$')
plt.xlabel('$Q_x$')

plt.tight_layout()
plt.axis('equal');
plt.xticks(rotation=45)
plt.grid()
plt.legend()


#plt.savefig('../DL2/1HO_foot_with_oct_0_sigma_bb_compare.png')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [156], line 17
#      14 plt.scatter(q_x[72:84],q_y[72:84], label = '6.0 $\sigma$ ', s=points)
#      16 for i in range(12):
# ---> 17     q_x_s1c = [q_x[0+i],q_x[12+i],q_x[24+i],q_x[36+i],q_x[48+i],q_x[60+i],q_x[72+i]]
#      18     q_y_s1c = [q_y[0+i],q_y[12+i],q_y[24+i],q_y[36+i],q_y[48+i],q_y[60+i],q_y[72+i]]
#      19     plt.plot(q_x_s1c,q_y_s1c,'darkgrey')
#
# IndexError: list index out of range

# %%
def get_max_tune(tracker):
    
    h = 6 # find 6 maxima along the spectrum 


    q_x = []
    for k in range(len(x_n)):
        naff_tune = NAFFlib.get_tunes_all(tracker.record_last_track.x[k].copy(),h)
        amp = []
        for i in range(h):

            amp.append(np.abs(naff_tune[1][i]))

        for i in range(h):      
            if amp[i]==np.max(amp):
                q_x.append(np.abs(naff_tune[0][i]))

    q_y = []
    for k in range(len(y_n)):
        naff_tune = NAFFlib.get_tunes_all(tracker.record_last_track.y[k].copy(),h)
        amp = []
        for i in range(h):
            amp.append(np.abs(np.abs(naff_tune[1][i])))

        for i in range(h):        
            if amp[i]==np.max(amp):
                q_y.append(np.abs(naff_tune[0][i]))
                
    return q_x, q_y

# %%
# Out:
# ([0.30093769986731755,
#   0.3009353318019346,
#   0.3009315491843957,
#   0.3009265851905675,
#   0.3009207474319062,
#   0.3009143995478489,
#   0.30090793918552294,
#   0.30090177324615947,
#   0.30089629216852787,
#   0.300891845342226,
#   0.3008887150026508,
#   0.3008871063200706,
#   0.30227768064750393,
#   0.302257432704589,
#   0.3022248711047405,
#   0.30218162127081827,
#   0.30212993810493205,
#   0.3020726693155978,
#   0.30201318080465617,
#   0.30195521721548424,
#   0.30190268330064757,
#   0.3018593469898456,
#   0.3018284798319305,
#   0.3018125095771837,
#   0.3049789811244166,
#   0.30494380845306335,
#   0.3048851770935504,
#   0.3048028210294102,
#   0.3046971863792003,
#   0.304570347299134,
#   0.3044270210190849,
#   0.3042753821534149,
#   0.3041271827723997,
#   0.3039968382939369,
#   0.3038993149995087,
#   0.3038471695406172,
#   0.30694324095925796,
#   0.3069229782324119,
#   0.306883935610446,
#   0.30681962625914616,
#   0.30672346073399653,
#   0.30659022577149236,
#   0.3064182756022361,
#   0.3062127362832249,
#   0.30598882401165167,
#   0.3057730773849411,
#   0.3055999445607557,
#   0.30550291198530516,
#   0.3080417031064385,
#   0.3080389286551503,
#   0.30802449120742975,
#   0.30798911905825077,
#   0.30792355565252827,
#   0.307818372969047,
#   0.30766484777134545,
#   0.30745799065747514,
#   0.30720402115699147,
#   0.3069334388421027,
#   0.3066932379609535,
#   0.30655136189108806,
#   0.30865957465184624,
#   0.30866594393149416,
#   0.30866440309360516,
#   0.30864587045380903,
#   0.30860341844079214,
#   0.30852753384257964,
#   0.30840687462690586,
#   0.3082292695617359,
#   0.3079955084354088,
#   0.30769736842678747,
#   0.3074115896595349,
#   0.30722822861906757,
#   0.30904156298840324,
#   0.30905154040040456,
#   0.30905523904615007,
#   0.30904475478776666,
#   0.30901520655461423,
#   0.3089598591263813,
#   0.30886852864882314,
#   0.30873090178443624,
#   0.3085269511277572,
#   0.30823955655900176,
#   0.30792442912687046,
#   0.3077043808435455],
#  [0.31111952885625743,
#   0.3111218787492811,
#   0.31112561783030274,
#   0.3111304984485499,
#   0.3111362015036537,
#   0.31114235960239744,
#   0.3111485822670897,
#   0.311154481269131,
#   0.31115969430756046,
#   0.3111639076967838,
#   0.3111668633686646,
#   0.3111683916433525,
#   0.31202450574666113,
#   0.3120521406959762,
#   0.3120949689941998,
#   0.3121489129329962,
#   0.312209322515944,
#   0.31227158721935344,
#   0.3123315736394213,
#   0.31238588551081686,
#   0.312431932829322,
#   0.312467880819209,
#   0.312492526299565,
#   0.3125051545171763,
#   0.3139123071669199,
#   0.31402658397014416,
#   0.3141905508082012,
#   0.31437811156663303,
#   0.3145669682250493,
#   0.3147413811699991,
#   0.31489200445385884,
#   0.3150146458651747,
#   0.31510874649616194,
#   0.3151759887510182,
#   0.31521898970341,
#   0.3152402044150032,
#   0.3154587035371121,
#   0.3156838597314333,
#   0.3159749145524829,
#   0.31627110063618524,
#   0.31653632827649597,
#   0.3167547756459325,
#   0.31692328806302117,
#   0.3170454773257217,
#   0.31712833153776365,
#   0.3171801672796746,
#   0.31720921598920443,
#   0.31722219624511916,
#   0.316519084540551,
#   0.31683195961725913,
#   0.31719409172496277,
#   0.3175221272452232,
#   0.31778512165084016,
#   0.31798084283526656,
#   0.31811824672213057,
#   0.3182084922272694,
#   0.3182631575169997,
#   0.3182892839792823,
#   0.3183011978483694,
#   0.318304553373419,
#   0.3172566346623761,
#   0.3176245841553802,
#   0.31800574901865797,
#   0.31831386877553147,
#   0.3185385998818568,
#   0.3186928879398095,
#   0.31879475641919736,
#   0.3188600750949556,
#   0.3188883079470912,
#   0.31890405147122025,
#   0.31890531310076764,
#   0.3189030619978315,
#   0.31779766792206376,
#   0.3181952318169429,
#   0.3185637954066219,
#   0.31883194411206134,
#   0.3190121541859928,
#   0.31913172102207366,
#   0.3192104019553998,
#   0.31924796336390643,
#   0.3192725472059223,
#   0.31928000019223723,
#   0.3192765823320833,
#   0.31927153448482926])

# %%
# plot the footprint 


def plot_footprint(qx,qy,coords_per_arc,title=str,):
    plot_object = plt.figure('FOOTPRINT')
    plt.suptitle(title)
    
    n = coords_per_arc

    points=8

    plt.scatter(q_x[0:n],q_y[0:n], label = '0.3 $\sigma$ ', s=points)
    plt.scatter(q_x[n:2*n],q_y[n:2*n], label = '1.0 $\sigma$ ',s=points)
    plt.scatter(q_x[2*n:3*n],q_y[2*n:3*n], label = '2.0 $\sigma$ ',s=points)
    plt.scatter(q_x[3*n:4*n],q_y[3*n:4*n], label = '3.0 $\sigma$', s=points)
    plt.scatter(q_x[4*n:5*n],q_y[4*n:5*n], label = '4.0 $\sigma$ ', s=points)
    plt.scatter(q_x[5*n:6*n],q_y[5*n:6*n], label = '5.0 $\sigma$ ', s=points)
    plt.scatter(q_x[6*n:7*n],q_y[6*n:7*n], label = '6.0 $\sigma$ ', s=points)

    for i in range(n):
        q_x_s1c = [q_x[0+i],q_x[n+i],q_x[2*n+i],q_x[3*n+i],q_x[4*n+i],q_x[5*n+i],q_x[6*n+i]]
        q_y_s1c = [q_y[0+i],q_y[n+i],q_y[2*n+i],q_y[3*n+i],q_y[4*n+i],q_y[5*n+i],q_y[6*n+i]]
        plt.plot(q_x_s1c,q_y_s1c,'darkgrey')



    plt.plot(q_x[0:n-1],q_y[0:n-1],color='darkgrey',)
    plt.plot(q_x[n:2*n-1],q_y[n:2*n-1],color='darkgrey',)
    plt.plot(q_x[2*n:3*n-1],q_y[2*n:3*n-1], color='darkgrey',)
    plt.plot(q_x[3*n:4*n-1],q_y[3*n:4*n-1], color='darkgrey',)
    plt.plot(q_x[4*n:5*n-1],q_y[4*n:5*n-1], color='darkgrey',)
    plt.plot(q_x[5*n:6*n-1],q_y[5*n:6*n-1],color='darkgrey',)
    plt.plot(q_x[6*n:7*n],q_y[6*n:7*n], color='darkgrey',)


    plt.ylabel('$Q_y$')
    plt.xlabel('$Q_x$')

    plt.tight_layout()
    plt.axis('equal');
    plt.xticks(rotation=45)
    plt.grid()
    plt.legend()

# %%
boo = plot_footprint(q_x,q_y,12,'hello')

# %%
plot_footprint(q_x,q_y,7,)
